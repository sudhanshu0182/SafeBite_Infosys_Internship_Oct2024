# %%
df = df.rename(columns={'Customer rating (Out of 5)': 'Customer rating', 'Price ($)':'Price'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = df.rename(columns={'Customer rating (Out of 5)': 'Customer rating', 'Price ($)':'Price'})
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv("Allergen_Status_of_Food_Products.csv")

# %%
df = df.rename(columns={'Customer rating (Out of 5)': 'Customer rating', 'Price ($)':'Price'})

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = {
'Category': ['Food Product', 'Price', 'Customer rating'],
'Values': ['Almonds',10.15,3.1],
'Other_Values': ['Cheese',18.9,4.2]
}
df = pd.DataFrame(data)
print(df)
# Out:
#           Category   Values Other_Values
# 0     Food Product  Almonds       Cheese
# 1            Price    10.15         18.9
# 2  Customer rating      3.1          4.2

# %%
plt.figure(figsize=(8, 5))
plt.plot(['Price'], marker='o', label='Price')
plt.plot(['Customer rating'], marker='s', label='Customer rating')
plt.title('Line Plot Example')
plt.xlabel('Category')
plt.ylabel('Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar( ['Food Product', 'Price'],
 ['Almond Cookies','10.15'],color='lightblue')
plt.title('Bar Plot Example')
plt.xlabel('Food Product')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.pie(['3.1','10.15'], labels=['Customer rating','Price'], autopct='%1.1f%%',
startangle=140)
plt.title('Pie Chart Example')

plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=['Main Ingredient','Food Product'], y=['Price','Customer rating'])
plt.title('Box Plot Example')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.figure(figsize=(8, 5))
sns.scatterplot(x=['Customer rating'], y=['Price'], hue=['Food Product'],
s=100)
plt.title('Scatter Plot with Seaborn')
plt.xlabel('Values')
plt.ylabel('Other Values')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(['Price'], bins=5, kde=True)
plt.title('Histogram of Values')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=['Main Ingredient','Price','Customer rating'], y=['Almonds','10.15','3.1'])
plt.title('Bar Plot to Save')
plt.savefig('bar_plot.png') 
plt.show()
